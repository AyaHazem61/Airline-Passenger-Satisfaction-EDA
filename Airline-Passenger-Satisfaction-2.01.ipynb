# %% [markdown]
# # UnderProgress

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('airline_passenger_satisfaction.csv')
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Gate Location  \
# 0                       3                 4                3              3
# 1                       2                 3                5              2
# 2                       4                 4                5              4
# 3                       2                 3                4              2
# 4                       3                 3                5              3
#
#    On-board Service  Seat Comfort  Leg Room Service  Cleanliness  \
# 0                 3             5                 2            5
# 1                 5             4                 5            5
# 2                 3             5                 3            5
# 3                 5             5                 5            4
# 4                 3             4                 4            5
#
#    Food and Drink  In-flight Service  In-flight Wifi Service  \
# 0               5                  5                       3
# 1               3                  5                       2
# 2               5                  3                       4
# 3               4                  5                       2
# 4               4                  3                       3
#
#    In-flight Entertainment  Baggage Handling             Satisfaction
# 0                        5                 5  Neutral or Dissatisfied
# 1                        5                 5                Satisfied
# 2                        3                 3                Satisfied
# 3                        5                 5                Satisfied
# 4                        3                 3                Satisfied

# %%
df.tail(5)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# 129875                                       4                       4
# 129876                                       5                       3
# 129877                                       5                       2
# 129878                                       4                       4
# 129879                                       1                       3
#
#         Check-in Service  Online Boarding  Gate Location  On-board Service  \
# 129875                 4                4              2                 5
# 129876                 5                3              4                 5
# 129877                 4                2              1                 3
# 129878                 3                4              1                 4
# 129879                 4                3              2                 4
#
#         Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# 129875             1                 4            4               4
# 129876             2                 5            2               2
# 129877             3                 4            3               3
# 129878             4                 5            3               3
# 129879             2                 4            2               2
#
#         In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# 129875                  5                       4                        4
# 129876                  4                       3                        2
# 129877                  4                       2                        3
# 129878                  4                       5                        3
# 129879                  2                       3                        2
#
#         Baggage Handling             Satisfaction
# 129875                 4  Neutral or Dissatisfied
# 129876                 5  Neutral or Dissatisfied
# 129877                 5  Neutral or Dissatisfied
# 129878                 5                Satisfied
# 129879                 1  Neutral or Dissatisfied

# %%
df.sample(5)
# Out:
#             ID  Gender  Age Customer Type Type of Travel     Class  \
# 49611    49612    Male   37     Returning       Business  Business
# 98861    98862  Female   41     Returning       Personal   Economy
# 93288    93289  Female   65     Returning       Personal   Economy
# 111257  111258    Male   26     Returning       Personal   Economy
# 115168  115169    Male   20    First-time       Business   Economy
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 49611               110                1            0.0
# 98861              1751                0            NaN
# 93288               806                0            0.0
# 111257             1972               14           17.0
# 115168              417                0            0.0
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# 49611                                        4                       4
# 98861                                        2                       4
# 93288                                        4                       3
# 111257                                       3                       2
# 115168                                       3                       1
#
#         Check-in Service  Online Boarding  Gate Location  On-board Service  \
# 49611                  4                3              4                 4
# 98861                  4                4              3                 1
# 93288                  5                2              2                 1
# 111257                 2                2              2                 1
# 115168                 3                1              3                 1
#
#         Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# 49611              3                 4            4               5
# 98861              1                 3            1               1
# 93288              5                 3            5               5
# 111257             4                 3            4               4
# 115168             2                 3            2               2
#
#         In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# 49611                   4                       4                        4
# 98861                   3                       4                        1
# 93288                   1                       3                        1
# 111257                  3                       2                        4
# 115168                  3                       1                        2
#
#         Baggage Handling             Satisfaction
# 49611                  4                Satisfied
# 98861                  3  Neutral or Dissatisfied
# 93288                  1  Neutral or Dissatisfied
# 111257                 2  Neutral or Dissatisfied
# 115168                 3  Neutral or Dissatisfied

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
#  10  Ease of Online Booking                  129880 non-null  int64
#  11  Check-in Service                        129880 non-null  int64
#  12  Online Boarding                         129880 non-null  int64
#  13  Gate Location                           129880 non-null  int64
#  14  On-board Service                        129880 non-null  int64
#  15  Seat Comfort                            129880 non-null  int64
#  16  Leg Room Service                        129880 non-null  int64
#  17  Cleanliness                             129880 non-null  int64
#  18  Food and Drink                          129880 non-null  int64
#  19  In-flight Service                       129880 non-null  int64
#  20  In-flight Wifi Service                  129880 non-null  int64
#  21  In-flight Entertainment                 129880 non-null  int64
#  22  Baggage Handling                        129880 non-null  int64
#  23  Satisfaction                            129880 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 23.8+ MB

# %%
nans = df.isna().sum().sort_values(ascending = False)
pct = (nans/df.shape[0]) * 100
pd.concat([nans, pct], axis = 1).rename(columns = {0 : 'NullValuesCount', 1 : 'NullValuesPercentage'}).head(5)
# Out:
#                          NullValuesCount  NullValuesPercentage
# Arrival Delay                        393              0.302587
# ID                                     0              0.000000
# Gate Location                          0              0.000000
# Baggage Handling                       0              0.000000
# In-flight Entertainment                0              0.000000

# %%
df.set_index('ID', inplace = True)

# %%
df[['Gender', 'Customer Type', 'Type of Travel', 'Class']] = df[['Gender', 'Customer Type', 'Type of Travel', 'Class']].astype('category')

for (column_index, column_name) in enumerate(df.iloc[:,8:]):
    df[column_name] = df[column_name].astype('category')

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Departure Delay  Arrival Delay
# count  129880.000000    129880.000000    129880.000000  129487.000000
# mean       39.427957      1190.316392        14.713713      15.091129
# std        15.119360       997.452477        38.071126      38.465650
# min         7.000000        31.000000         0.000000       0.000000
# 25%        27.000000       414.000000         0.000000       0.000000
# 50%        40.000000       844.000000         0.000000       0.000000
# 75%        51.000000      1744.000000        12.000000      13.000000
# max        85.000000      4983.000000      1592.000000    1584.000000

# %%
df.describe(include = 'category')
# Out:
#         Gender Customer Type Type of Travel     Class  \
# count   129880        129880         129880    129880
# unique       2             2              2         3
# top     Female     Returning       Business  Business
# freq     65899        106100          89693     62160
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# count                                   129880                  129880
# unique                                       6                       6
# top                                          4                       3
# freq                                     31880                   30393
#
#         Check-in Service  Online Boarding  Gate Location  On-board Service  \
# count             129880           129880         129880            129880
# unique                 6                6              6                 6
# top                    4                4              3                 4
# freq               36333            38468          35717             38703
#
#         Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# count         129880            129880       129880          129880
# unique             6                 6            6               6
# top                4                 4            4               4
# freq           39756             35886        33969           30563
#
#         In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# count              129880                  129880                   129880
# unique                  6                       6                        6
# top                     4                       2                        4
# freq                47323                   32320                    36791
#
#         Baggage Handling             Satisfaction
# count             129880                   129880
# unique                 5                        2
# top                    4  Neutral or Dissatisfied
# freq               46761                    73452

# %%
df['Satisfaction'].unique()
# Out:
# ['Neutral or Dissatisfied', 'Satisfied']
# Categories (2, object): ['Neutral or Dissatisfied', 'Satisfied']

# %%
sns.catplot(x = 'Satisfaction', data = df, kind = 'count', order = ['Satisfied', 'Neutral or Dissatisfied'], palette = 'Purples')

plt.show()

# %%
df['Gender'].unique()
# Out:
# ['Male', 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
sns.catplot(x = 'Gender', data = df, kind = 'count', order = ['Female', 'Male'], palette = 'Purples')

plt.show()

# %%
df['Age'].describe()
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
fig, ax = plt.subplots(1,2, figsize = (12, 6))

sns.histplot(x = 'Age', data = df, bins = 80, binrange = (10,80), ax = ax[0], color = '#9e9ac8')
sns.boxplot(y = 'Age', data = df, ax = ax[1], color = '#9e9ac8')

fig.suptitle('Age Distribution', fontsize = 20)
plt.show()

# %%
corr_m = df[['Age','Flight Distance','Departure Delay', 'Arrival Delay']].dropna().astype('int').corr()

# %%
sns.heatmap(corr_m, square = True, cmap = 'Purples')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (6,6))

sns.scatterplot(x = 'Departure Delay', y = 'Arrival Delay', data = df.dropna(), color = '#756bb1', ax = ax)
ax.set_ylim(0,1600)

plt.show()

# %% [markdown]
# There is a strong linear corralation between `'Departure Delay'` and `'Arrival Delay'`

# %%
subdf = df[['Arrival Delay', 'Departure Delay']].dropna().astype('int')

fig, ax = plt.subplots(1,2, figsize = (12, 6))

sns.boxplot(y = 'Arrival Delay', data = subdf,ax = ax[0])

sns.boxplot(y = 'Departure Delay',data = subdf, ax = ax[1])

plt.show()

# %%
outliers = (subdf['Arrival Delay'] > 300) | (subdf['Departure Delay'] > 300)
subdf.drop(subdf[outliers].index, inplace = True)

# %%
from scipy.stats import linregress

obj = linregress(subdf['Departure Delay'], subdf['Arrival Delay'] )


compute_arr = lambda x: obj.intercept + (obj.slope * x)

xs = np.array([0,300])
ys = compute_arr(xs)
obj
# Out:
# LinregressResult(slope=0.9672250436337665, intercept=0.8794427263536697, rvalue=0.9513365911698067, pvalue=0.0, stderr=0.000871799964674179)

# %%
fig, ax = plt.subplots(figsize = (6,6))

sns.scatterplot(x = 'Departure Delay', y = 'Arrival Delay', data = subdf, color = '#756bb1', ax = ax)
ax.plot(xs, ys, alpha = 0.4)

plt.show()

# %% [markdown]
# I will be using this linear regression oject to compute missing values in `'Arrival Delay'`

# %%
missing = df['Arrival Delay'].isna()

xs = df.loc[missing, 'Departure Delay']

ys = compute_arr(xs)

df.loc[missing, 'Arrival Delay'] = ys

# %%
fig, ax = plt.subplots(figsize = (6,6))

sns.scatterplot(x = 'Departure Delay', y = 'Arrival Delay', data = df, color = '#756bb1', ax = ax)

plt.show()
